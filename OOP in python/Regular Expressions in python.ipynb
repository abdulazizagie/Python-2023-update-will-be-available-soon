# %% [markdown]
# ### Regular Expressions in python
# Regular expression, or "regex" for short , ae a powerful tool for wprking with strings and text data in python.They allow you to match and manipulate string based on patterns, makinf it easy to perform comples string operations with just a few lines of code.
#
# ### Matacharacters in regular expressions
# ```python
# [] Represent a character class Matches the beginning
# $ mathch any the end
# . Matches any character except newline
# ? Matches zero or one accurrence.
# | Means OR (Matches with any of the charachers
#                                     separated by it.)
# * Any number of occurrences
# (including 0 occurrences)
# + une or more occurrences
# {} Indicate number of occurrences of a preceding RE to match.
# () Enclose a group of REs
# ```
# Find list of more character here - https://www.ibm.com/docs/en/en/rational-clearquest/9.0.1?topic=tas-mata-characters-in-regular-expressions
#
# ### Importing re Package
# In python , regular expressions are supported by the `re` module.The basic syntax for working with regular expressions in python is as follows:
# ```python
# import re
# ```
# ### Searching for a pattern in re using re.search() Method
# re.search() method either return None (if the pattern doesn't match),or a re.MatchObject that contains information aboutt the matching part of the string.This method stops after the first match,so thi best suited for testing a regular expression more than extracting data.We can use re.search method like this to search for a pattern in regular expression:
# ```python
# #Define a regular expression pattern
# pattern = r"expression"
#
# # Match the pattern against a string
# text = "Hello, world!"
#
# match = re.search(pattern,text)
#
# if match:
#     print("Match found!")
# else:
#     print("Match not found")
# ```
# ### Searching for a pattern in re using re.findall() Method
#
# You can also use the re.findall findall funcation to find all occurrences of the pattern is a string:
# ```python
# import re
# pattern = r"expression"
# text = "The cat is in the hat."
#
# matches = re.findall(pattern, text)
# print(matches)
# ```
# ### Replacing a pattern
# The following example shows how to replace a pattern in a string:
#
# ```python
# import re
# pattern = r"[a-z]+at"
# text = "The cat is in the hat."
#
# matches = re.findall(pattern,text)
#
# parint(matches)
#
# new_text = re.sub(pattern,"dog",text)
#
# print(new_text)
# ```

# %%
import re

patterns = r"[A-Z]yclone"
text = '''Cyclone Dumazile was a strong tro
pical cyclone in the South-West Indian Ocean 
that affeted Madagescar and Reunion in early
March 2018.Dumazile originated from a cyclon
Dyclone low-pressur area that fromed near  
Agalega on 27 February.It became a tropical 
disturbance on 2 March, and was named the next
day after attanining tropical storm status.
Dumazile reached its peak intensity on 5 March,
with 10 minte sustained winds of 165 km/h (105 
mph), 1-minte sustained winds of 205 km/h (125 m
ph),and a central atmospheric pressure of 945 hPa 
(27.81 inHh). As it tracked southeastwards, Dumazile 
weakened steadily over the next couple of days due
to wind shear, and becane a post tropical cyclone on 7 March '''


macthes = re.finditer(patterns,text)
for match in macthes:
    print(match.span())
    print(text[match.span()[0]:match.span()[1]])

# match = re.search(patterns,text)
# print(match)
# Out:
# (0, 7)
# Cyclone
# (170, 177)
# Dyclone
