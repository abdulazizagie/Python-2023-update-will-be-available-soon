# %% [markdown]
# ### Exercise 10
# Use the NewsAPI and the requests module to fetch the daily news related to different topics.Go to :http://newsapi.org/ and explore the various options to build you application

# %%
import requests

url = "https://newsapi.org/v2/everything?q=tesla&from=2023-08-12&sortBy=publishedAt&apiKey=22a0a5732c5e4de9abfa6bad210ed8c8"
response = requests.get(url)
print(response.text)

# %%
# import pandas as pd
# news_data = pd.DataFrame(response.json()['articles'])
# response.json()['articles']

# %%
# print('''source == 1
# author == 2
# title ==  3
# description == 4
# url == 5
# urlToImage == 6
# publishedAt == 7
# content == 8''')
# user = int(input("select the option is: "))
# for i in news_data:
#     if user == 1:
#         pass
#     elif user == 2:
#         print(news_data['author'])
#         break
#     elif user == 3:
#         print(news_data['title'])
#         break
#     elif user == 4:
#         print(news_data['description'])
#         break
#     elif user == 5:
#         print(news_data['url'])
#         break
#     elif user == 6:
#         print(news_data['urlToImage'])
#         break
#     elif user == 7:
#         print(news_data['publishedAt'])
#         break
#     elif user == 8:
#         print(news_data['content'])
#         break

# %%
# import argparse
# url = news_data['urlToImage']
# output = news_data['title']
# def download_file(url,local_filename):
#     if local_filename is None:
#         local_filename = url.split('/')[-1]
#         # Not the stream =True parameter below
#     with requests.get(url,stream=True) as r:
#         r.raise_for_status()
#         with open(local_filename,'wb') as f:
#             for chunk  in r.iter_content(chunk_size=8192):
#                     f.write(chunk)
#     return local_filename

# parser = argparse.ArgumentParser()

# # add command line argumants
# parser.add_argument("url",help="Url of the file to download")

# parser.add_argument("-o","--output",type=str,help="Name of the file",default=None)

# # Parser the arGUMANTS
# args = parser.parse_args()


# # Use the argumant is your code
# print(args.url)
# print(args.output,type(args.output))
# download_file(args.url,args.output)

# %%
import requests
import json
query = input("What type of news are you interested in? ")
url = f"https://newsapi.org/v2/everything?q={query}&from=2023-08-13&sortBy=publishedAt&apiKey=22a0a5732c5e4de9abfa6bad210ed8c8"
r = requests.get(url)
print(r.text)
r = requests.get(url)
news = json.loads(r.text)
print(news ,type(news))
# Out:
# {"status":"ok","totalResults":3285,"articles":[{"source":{"id":null,"name":"kicker"},"author":"kicker","title":"Bayern-Chefin Rech im Interview: \"Es wird fast keine Delle in der Liga geben\"","description":"Nach der Weltmeisterschaft ist vor der Bundesliga: Bianca Rech (42), Bayerns Abteilungsleiterin Frauenfußball, geht mit sehr viel Optimismus und zwei internationalen Top-Stars in die neue Saison.","url":"https://www.kicker.de/bayern-chefin-rech-im-interview-es-wird-fast-keine-delle-in-der-liga-geben-967700/artikel","urlToImage":"https://derivates.kicker.de/image/upload/c_crop,x_0,y_184,w_3715,h_2090/w_1200,q_auto/v1/2023/09/08/25c3a444-d1e7-4b09-8bd1-d2a27dbe6c4b.jpeg","publishedAt":"2023-09-12T16:47:18Z","content":"Nach der Weltmeisterschaft ist vor der Bundesliga: Bianca Rech (42), Bayerns Abteilungsleiterin Frauenfußball, geht mit sehr viel Optimismus und zwei internationalen Top-Stars in die neue Saison. \r\n … [+11932 chars]"},{"source":{"id":null,"name":"NDTV News"},"author
# ...
